# %%
import random
from itertools import count
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')

# %%
x_vals = [0, 1, 2, 3, 4, 5]
y_vals = [0, 1, 3, 2, 3, 5]

plt.plot(x_vals, y_vals)

plt.tight_layout()
plt.show()

# %%
# %matplotlib nbagg

from matplotlib import animation
from matplotlib import rc
from IPython.display import HTML

plt.rcParams['animation.ffmpeg_path'] = '/Users/salma/anaconda3/envs/visualization/share/ffmpeg'

index = count()

def animate(i):
    x_vals.append(next(index))
    y_vals.append(random.randint(0, 5))
    
    plt.plot(x_vals, y_vals)
    
ani = animation.FuncAnimation(plt.gcf(), animate, interval=1000) # interval in ms
Writer = animation.FFMpegWriter(fps=30, codec='libx264')

#Writer = animation.FFMpegWriter(fps=20, metadata=dict(artist='Me'), bitrate=1800)

HTML(ani.to_html5_video())
#rc('animation', html='html5')

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/visualization/lib/python3.8/site-packages/matplotlib/animation.py in __getitem__(self, name)
#     160         try:
# --> 161             return self.avail[name]
#     162         except KeyError:
#
# KeyError: 'ffmpeg'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-28-64d1d8b686c5> in <module>
#      20 #Writer = animation.FFMpegWriter(fps=20, metadata=dict(artist='Me'), bitrate=1800)
#      21
# ---> 22 HTML(ani.to_html5_video())
#      23 #rc('animation', html='html5')
#      24
#
# ~/anaconda3/envs/visualization/lib/python3.8/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
# ...

# %%
#%matplotlib nbagg


from matplotlib import animation
from matplotlib import rc
from IPython.display import HTML

import random
from itertools import count
import pandas as pd
import matplotlib.pyplot as plt

x_vals = []
y_vals = []

index = count()

def animate(i):
    x_vals.append(next(index))
    y_vals.append(random.randint(0, 5))
    
    plt.cla()
    plt.plot(x_vals, y_vals)
    
ani = animation.FuncAnimation(plt.gcf(), animate, interval=1000) # interval in ms


plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib

matplotlib.get_backend()
# Out:
# 'nbAgg'

# %%
#%matplotlib nbagg

from matplotlib import animation
from matplotlib import rc
from IPython.display import HTML

import random
from itertools import count
import pandas as pd
import matplotlib.pyplot as plt

x_vals = []
y_vals = []

index = count()


def animate(i):
    
    data = pd.read_csv('data/live_data.csv')
    
    x = data['x_value']
    y1 = data['total_1']
    y2 = data['total_2']
    
    plt.cla()
    plt.plot(x, y1, label='Channel 1')
    plt.plot(x, y2, label='Channel 2')
    
    plt.legend(loc='upper left')
    plt.tight_layout()
    
    
ani = animation.FuncAnimation(plt.gcf(), animate, interval=1000) # interval in ms


plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
